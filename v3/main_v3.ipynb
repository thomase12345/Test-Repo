# %%
# !python train.py
# Out:
# --- TRUE PITCH DISTRIBUTION (V2) ---
#  CU :  18.21%  (626 pitches)
#  FC :  10.97%  (377 pitches)
#  FF :  34.68%  (1192 pitches)
#  FS :  26.01%  (894 pitches)
#  SI :   7.24%  (249 pitches)
#  SL :   2.85%  (98 pitches)
#  ST :   0.03%  (1 pitches)
# Epoch 01 | Train Loss: 1.8513 | Val Loss: 1.6835 | Val Acc: 0.3794
# Epoch 02 | Train Loss: 1.7758 | Val Loss: 1.6638 | Val Acc: 0.3663
# Epoch 03 | Train Loss: 1.7473 | Val Loss: 1.6347 | Val Acc: 0.3794
# Epoch 04 | Train Loss: 1.7273 | Val Loss: 1.6207 | Val Acc: 0.3605
# Epoch 05 | Train Loss: 1.6986 | Val Loss: 1.5872 | Val Acc: 0.3576
# Epoch 06 | Train Loss: 1.6570 | Val Loss: 1.5761 | Val Acc: 0.3459
# Epoch 07 | Train Loss: 1.6260 | Val Loss: 1.5778 | Val Acc: 0.3474
# Epoch 08 | Train Loss: 1.6081 | Val Loss: 1.5307 | Val Acc: 0.3924
# Epoch 09 | Train Loss: 1.5915 | Val Loss: 1.5317 | Val Acc: 0.3808
# Epoch 10 | Train Loss: 1.5664 | Val Loss: 1.5079 | Val Acc: 0.3852
# ...

# %%
# !python evaluate.py
# Out:
# OVERALL VALIDATION ACCURACY: 0.3948
#
# PER-PITCH ACCURACY:
#  CU : 0.0767  (n=626)
#  FC : 0.1777  (n=377)
#  FF : 0.5797  (n=1192)
#  FS : 0.4306  (n=894)
#  SI : 0.5703  (n=249)
#  SL : 0.2449  (n=98)
#  ST : 0.0000  (n=1)
#
# Saved confusion matrix to confusion_matrix_v2.png
